# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt # plotting
import PdM_functions as pdm # custom functions created for this project that are used in several notebooks

# %%
# Load the radiator flow data
df_set_train = pd.read_csv('data/Space Shuttle/shuttle.trn', sep = " ", header=None).drop(0, axis = 1)
df_set_test = pd.read_csv('data/Space Shuttle/shuttle.tst', sep = " ", header=None).drop(0, axis = 1)
df_set_train['timestamp'] = list(range(1, len(df_set_train) + 1, 1))
df_set_test['timestamp'] = list(range(len(df_set_train) + 1, (len(df_set_train) +len(df_set_test) + 1), 1))

# %%
print(df_set_train)
print(df_set_test)
# Out:
#         1    2  3   4   5   6   7   8  9  timestamp
# 0      21   77  0  28   0  27  48  22  2          1
# 1       0   92  0   0  26  36  92  56  4          2
# 2       0   82  0  52  -5  29  30   2  1          3
# 3       0   76  0  28  18  40  48   8  1          4
# 4       0   79  0  34 -26  43  46   2  1          5
# ...    ..  ... ..  ..  ..  ..  ..  .. ..        ...
# 43495   5   78  0  46   5  32  32   0  1      43496
# 43496   0   79 -1  10   3  43  69  26  1      43497
# 43497   0   78  3  46   0  30  32   2  1      43498
# 43498   0   79  0  38 -25  38  40   2  1      43499
# 43499  -3  100  0  38   0  61  62   2  1      43500
#
# [43500 rows x 10 columns]
#        1    2  3   4   5   6    7    8  9  timestamp
# 0      0   81  0  -6  11  25   88   64  4      43501
# 1      0   96  0  52  -4  40   44    4  4      43502
# 2     -1   89 -7  50   0  39   40    2  1      43503
# 3      9   79  0  42  -2  25   37   12  4      43504
# 4      2   82  0  54  -6  26   28    2  1      43505
# ...   ..  ... ..  ..  ..  ..  ...  ... ..        ...
# 14495  0   84  0 -36 -29   4  120  116  5      57996
# 14496  0   81  0 -20  25  26  102   76  4      57997
# 14497  0   77  0  12 -22  22   65   42  4      57998
# 14498  0  103  0  18 -16  66   85   20  1      57999
# 14499  2   98  0  52   1  42   46    4  4      58000
#
# [14500 rows x 10 columns]

# %%
new_column_names = {
    0: 'timestamp',
    1: 'rad01',
    2: 'rad02',
    3: 'rad03',
    4: 'rad04',
    5: 'rad05',
    6: 'rad06',
    7: 'rad07',
    8: 'rad08',
    9: 'state'
    }

# %%
df_set_train.rename(columns = new_column_names, inplace = True)
df_set_test.rename(columns = new_column_names, inplace = True)

# %%
state_map = {
    1: 'Rad Flow',
    2: 'Fpv Close',
    3: 'Fpv Open',
    4: 'High',
    5: 'Bypass',
    6: 'Bpv Close',
    7: 'Bpv Open'
    }

# %%
df_set_train['state'].unique()
# Out:
# array([2, 4, 1, 5, 3, 7, 6])

# %%
df_set_test['state'].unique()
# Out:
# array([4, 1, 5, 3, 2, 7, 6])

# %%
state_map_an = {
    1: 'Normal',
    2: 'Anomaly',
    3: 'Anomaly',
    4: 'Anomaly',
    5: 'Anomaly',
    6: 'Anomaly',
    7: 'Anomaly'
    }

# %%
df_set_train['state'] = df_set_train['state'].map(state_map_an)
df_set_test['state'] = df_set_test['state'].map(state_map_an)

# %%
len(df_set_train.loc[df_set_train['state'] == 'Normal',:])
# Out:
# 34108

# %%
all_rows = len(df_set_train['state'])
norm_count = len(df_set_train.loc[df_set_train['state'] == 'Normal',:])
print('Normal fraction:', round(norm_count / all_rows, 2))
# Out:
# Normal fraction: 0.78

# %%
print(df_set_train)
print(df_set_test)
# Out:
#        rad01  rad02  rad03  rad04  rad05  rad06  rad07  rad08    state  \
# 0         21     77      0     28      0     27     48     22  Anomaly
# 1          0     92      0      0     26     36     92     56  Anomaly
# 2          0     82      0     52     -5     29     30      2   Normal
# 3          0     76      0     28     18     40     48      8   Normal
# 4          0     79      0     34    -26     43     46      2   Normal
# ...      ...    ...    ...    ...    ...    ...    ...    ...      ...
# 43495      5     78      0     46      5     32     32      0   Normal
# 43496      0     79     -1     10      3     43     69     26   Normal
# 43497      0     78      3     46      0     30     32      2   Normal
# 43498      0     79      0     38    -25     38     40      2   Normal
# 43499     -3    100      0     38      0     61     62      2   Normal
#
#        timestamp
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5
# ...          ...
# 43495      43496
# 43496      43497
# 43497      43498
# 43498      43499
# 43499      43500
#
# [43500 rows x 10 columns]
#        rad01  rad02  rad03  rad04  rad05  rad06  rad07  rad08    state  \
# 0          0     81      0     -6     11     25     88     64  Anomaly
# 1          0     96      0     52     -4     40     44      4  Anomaly
# 2         -1     89     -7     50      0     39     40      2   Normal
# 3          9     79      0     42     -2     25     37     12  Anomaly
# 4          2     82      0     54     -6     26     28      2   Normal
# ...      ...    ...    ...    ...    ...    ...    ...    ...      ...
# 14495      0     84      0    -36    -29      4    120    116  Anomaly
# 14496      0     81      0    -20     25     26    102     76  Anomaly
# 14497      0     77      0     12    -22     22     65     42  Anomaly
# 14498      0    103      0     18    -16     66     85     20   Normal
# 14499      2     98      0     52      1     42     46      4  Anomaly
#
#        timestamp
# 0          43501
# 1          43502
# 2          43503
# 3          43504
# 4          43505
# ...          ...
# 14495      57996
# 14496      57997
# 14497      57998
# 14498      57999
# 14499      58000
#
# [14500 rows x 10 columns]

# %%
df_set_train.describe()
# Out:
#               rad01         rad02         rad03         rad04         rad05  \
# count  43500.000000  43500.000000  43500.000000  43500.000000  43500.000000
# mean      -0.205126     85.341563      0.262736     34.528782      1.298276
# std       78.142770      8.908602     41.004131     21.703409    179.486760
# min    -4821.000000     21.000000  -3939.000000   -188.000000 -13839.000000
# 25%        0.000000     79.000000      0.000000     26.000000     -5.000000
# 50%        0.000000     83.000000      0.000000     42.000000      0.000000
# 75%        0.000000     89.000000      0.000000     46.000000      5.000000
# max     5075.000000    149.000000   3830.000000    436.000000  13148.000000
#
#               rad06         rad07         rad08     timestamp
# count  43500.000000  43500.000000  43500.000000  43500.000000
# mean      37.074552     50.899862     13.964598  21750.500000
# std       13.135557     21.463250     25.648404  12557.512692
# min      -48.000000   -353.000000   -356.000000      1.000000
# 25%       31.000000     37.000000      0.000000  10875.750000
# 50%       39.000000     44.000000      2.000000  21750.500000
# 75%       42.000000     60.000000     14.000000  32625.250000
# max      105.000000    270.000000    266.000000  43500.000000

# %%
# Check the results of cleaning
#plot_chans = ['volt', 'rotate', 'pressure', 'vibration', 'errorID', 'failure', 'maintenance']
for sen in df_set_train.columns[:-2]:
    df_set_train[[sen]].plot(figsize = (18, 4), color = 'black', marker = 'o')

# %% [markdown]
# ### Data Scaling

# %%
from sklearn import preprocessing
from sklearn.decomposition import PCA
from matplotlib import gridspec
from matplotlib.pyplot import figure
from itertools import groupby

# %%
df_set_train['state'].unique()
# Out:
# array(['Anomaly', 'Normal'], dtype=object)

# %%
df_set_train
# Out:
#        rad01  rad02  rad03  rad04  rad05  rad06  rad07  rad08    state  \
# 0         21     77      0     28      0     27     48     22  Anomaly
# 1          0     92      0      0     26     36     92     56  Anomaly
# 2          0     82      0     52     -5     29     30      2   Normal
# 3          0     76      0     28     18     40     48      8   Normal
# 4          0     79      0     34    -26     43     46      2   Normal
# ...      ...    ...    ...    ...    ...    ...    ...    ...      ...
# 43495      5     78      0     46      5     32     32      0   Normal
# 43496      0     79     -1     10      3     43     69     26   Normal
# 43497      0     78      3     46      0     30     32      2   Normal
# 43498      0     79      0     38    -25     38     40      2   Normal
# 43499     -3    100      0     38      0     61     62      2   Normal
#
#        timestamp
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5
# ...          ...
# 43495      43496
# 43496      43497
# 43497      43498
# 43498      43499
# 43499      43500
#
# [43500 rows x 10 columns]

# %%
# Scale the data (between 0 and 1)
drops = ['timestamp', 'state']
df_num_train = df_set_train.drop(drops, axis = 1)
scaler = preprocessing.MinMaxScaler()
#scaler = preprocessing.RobustScaler()
df_train_scaled = pd.DataFrame(scaler.fit_transform(df_num_train), columns = df_num_train.columns, index = df_num_train.index)
df_train_scaled['timestamp'] = df_set_train['timestamp']
df_train_scaled['state'] = df_set_train['state']
df_train_scaled.describe()
# Out:
#               rad01         rad02         rad03         rad04         rad05  \
# count  43500.000000  43500.000000  43500.000000  43500.000000  43500.000000
# mean       0.487146      0.502668      0.507049      0.356617      0.512851
# std        0.007896      0.069598      0.005278      0.034781      0.006651
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.487167      0.453125      0.507015      0.342949      0.512617
# 50%        0.487167      0.484375      0.507015      0.368590      0.512802
# 75%        0.487167      0.531250      0.507015      0.375000      0.512988
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#               rad06         rad07         rad08     timestamp
# count  43500.000000  43500.000000  43500.000000  43500.000000
# mean       0.556043      0.648314      0.594798  21750.500000
# std        0.085853      0.034451      0.041235  12557.512692
# min        0.000000      0.000000      0.000000      1.000000
# 25%        0.516340      0.626003      0.572347  10875.750000
# 50%        0.568627      0.637239      0.575563  21750.500000
# 75%        0.588235      0.662921      0.594855  32625.250000
# max        1.000000      1.000000      1.000000  43500.000000

# %%
df_num_test = df_set_test.drop(drops, axis = 1)
df_test_scaled = pd.DataFrame(scaler.transform(df_num_test), columns = df_num_test.columns, index = df_num_test.index)
df_test_scaled['timestamp'] = df_set_test['timestamp']
df_test_scaled['state'] = df_set_test['state']
df_test_scaled.describe()
# Out:
#               rad01         rad02         rad03         rad04         rad05  \
# count  14500.000000  14500.000000  14500.000000  14500.000000  14500.000000
# mean       0.487221      0.502905      0.507047      0.356752      0.512897
# std        0.007821      0.069418      0.002197      0.034504      0.011285
# min        0.167745      0.148438      0.460420      0.227564     -0.478008
# 25%        0.487167      0.453125      0.507015      0.346154      0.512654
# 50%        0.487167      0.484375      0.507015      0.368590      0.512802
# 75%        0.487167      0.531250      0.507015      0.375000      0.513025
# max        0.941997      0.757812      0.732398      0.798077      1.074703
#
#               rad06         rad07         rad08     timestamp
# count  14500.000000  14500.000000  14500.000000  14500.000000
# mean       0.556507      0.648216      0.594591  50750.500000
# std        0.085223      0.034161      0.041015   4185.933787
# min        0.196078      0.260032      0.147910  43501.000000
# 25%        0.522876      0.626003      0.572347  47125.750000
# 50%        0.568627      0.635634      0.575563  50750.500000
# 75%        0.588235      0.662921      0.594855  54375.250000
# max        0.790850      0.776886      0.774920  58000.000000

# %%
# Create map to reduce categories to two
# We want to remove 'recovering' so combine it with 'broken'
condition_map = {'Normal': 'Normal', 'Anomaly': 'Anomaly'}

# %%
df_train_scaled.head(10)
# Out:
#       rad01     rad02     rad03     rad04     rad05     rad06     rad07  \
# 0  0.489289  0.437500  0.507015  0.346154  0.512802  0.490196  0.643660
# 1  0.487167  0.554688  0.507015  0.301282  0.513766  0.549020  0.714286
# 2  0.487167  0.476562  0.507015  0.384615  0.512617  0.503268  0.614767
# 3  0.487167  0.429688  0.507015  0.346154  0.513469  0.575163  0.643660
# 4  0.487167  0.453125  0.507015  0.355769  0.511839  0.594771  0.640449
# 5  0.487167  0.523438  0.506500  0.310897  0.512840  0.333333  0.699839
# 6  0.487167  0.468750  0.507015  0.294872  0.513210  0.477124  0.704655
# 7  0.487065  0.578125  0.506629  0.387821  0.512654  0.575163  0.632424
# 8  0.487975  0.437500  0.507015  0.346154  0.512802  0.464052  0.643660
# 9  0.487167  0.625000  0.506114  0.346154  0.512802  0.732026  0.683788
#
#       rad08  timestamp    state
# 0  0.607717          1  Anomaly
# 1  0.662379          2  Anomaly
# 2  0.575563          3   Normal
# 3  0.585209          4   Normal
# 4  0.575563          5   Normal
# 5  0.700965          6  Anomaly
# 6  0.672026          7  Anomaly
# 7  0.575563          8   Normal
# 8  0.610932          9  Anomaly
# 9  0.585209         10   Normal

# %%
# Use besploke function from pdm_functions
df_norm_train, df_abnorm_train = pdm.remove_segements(
    segment_vec = df_train_scaled['state'],
    mapping = condition_map,
    dat = df_train_scaled,
    trans_window = 0,
    keep = 'Normal'
)
# Out:
# Input segement categories:  ['Anomaly' 'Normal']
# Categories after mapping:  ['Anomaly' 'Normal']
# Run length encoding:  [('Anomaly', 2), ('Normal', 3), ('Anomaly', 2), ('Normal', 1), ('Anomaly', 1), ('Normal', 12), ('Anomaly', 1), ('Normal', 4), ('Anomaly', 1), ('Normal', 5), ('Anomaly', 1), ('Normal', 3), ('Anomaly', 1), ('Normal', 5), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 1), ('Normal', 3), ('Anomaly', 1), ('Normal', 2), ('Anomaly', 1), ('Normal', 6), ('Anomaly', 2), ('Normal', 4), ('Anomaly', 2), ('Normal', 9), ('Anomaly', 1), ('Normal', 2), ('Anomaly', 1), ('Normal', 18), ('Anomaly', 1), ('Normal', 4), ('Anomaly', 1), ('Normal', 5), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 1), ('Normal', 2), ('Anomaly', 2), ('Normal', 1), ('Anomaly', 1), ('Normal', 12), ('Anomaly', 1), ('Normal', 19), ('Anomaly', 1), ('Normal', 4), ('Anomaly', 1), ('Normal', 5), ('Anomaly', 1), ('Normal', 8), ('Anomaly', 1), ('Normal', 2), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 2), ('Normal', 4), ('Anomaly', 2), ('Normal', 1), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 1), ('Normal', 8), ('Anomaly', 2), ('Normal', 2), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 1), ('Normal', 4), ('Anomaly', 1), ('Normal', 17), ('Anomaly', 2), ('Normal', 1), ('Anomaly', 1), ('Normal', 4), ('Anomaly', 1), ('Normal', 4), ('Anomaly', 1), ('Normal', 8), ('Anomaly', 1), ('Normal', 5), ('Anomaly', 1), ('Normal', 3), ('Anomaly', 1), ('Normal', 6), ('Anomaly', 1), ('Normal', 3), ('Anomaly', 1), ('Normal', 8), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 1), ('Normal', 3), ('Anomaly', 1), ('Normal', 3), ('Anomaly', 2), ('Normal', 4), ('Anomaly', 1), ('Normal', 2), ('Anomaly', 1), ('Normal', 2), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 1), ('Normal', 11), ('Anomaly', 1), ('Normal', 6), ('Anomaly', 1), ('Normal', 9), ('Anomaly', 1), ('Normal', 2), ('Anomaly', 1), ('Normal', 2), ('Anomaly', 1), ('Normal', 11), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 1), ('Normal', 3), ('Anomaly', 1), ('Normal', 2), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 1), ('Normal', 4), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 1), ('Normal', 3), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 1), ('Normal', 21), ('Anomaly', 3), ('Normal', 4), ('Anomaly', 1), ('Normal', 8), ('Anomaly', 1), ('Normal', 11), ('Anomaly', 1), ('Normal', 4), ('Anomaly', 1), ('Normal', 2), ('Anomaly', 1), ('Normal', 4), ('Anomaly', 2), ('Normal', 1), ('Anomaly', 1), ('Normal', 4), ('Anomaly', 1), ('Normal', 2), ('Anomaly', 1), ('Normal', 2), ('Anomaly', 1), ('Normal', 14), ('Anomaly', 2), ('Normal', 1), ('Anomaly', 1), ('Normal', 10), ('Anomaly', 2), ('Normal', 2), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 1), ('Normal', 17), ('Anomaly', 2), ('Normal', 2), ('Anomaly', 2), ('Normal', 2), ('Anomaly', 2), ('Normal', 1), ('Anomaly', 1), ('Normal', 17), ('Anomaly', 1), ('Normal', 3), ('Anomaly', 3), ('Normal', 4), ('Anomaly', 1), ('Normal', 4), ('Anomaly', 1), ('Normal', 10), ('Anomaly', 1), ('Normal', 8), ('Anomaly', 1), ('Normal', 10), ('Anomaly', 1), ('Normal', 12), ('Anomaly', 1), ('Normal', 3), ('Anomaly', 1), ('Normal', 16), ('Anomaly', 1), ('Normal', 4), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 1), ('Normal', 14), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 1), ('Normal', 9), ('Anomaly', 1), ('Normal', 14), ('Anomaly', 1), ('Normal', 4), ('Anomaly', 1), ('Normal', 2), ('Anomaly', 1), ('Normal', 10), ('Anomaly', 1), ('Normal', 11), ('Anomaly', 1), ('Normal', 4), ('Anomaly', 1), ('Normal', 5), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 1), ('Normal', 13), ('Anomaly', 2), ('Normal', 12), ('Anomaly', 1), ('Normal', 3), ('Anomaly', 1), ('Normal', 11), ('Anomaly', 2), ('Normal', 5), ('Anomaly', 5), ('Normal', 3), ('Anomaly', 1), ('Normal', 3), ('Anomaly', 1), ('Normal', 5), ('Anomaly', 2), ('Normal', 13), ('Anomaly', 1), ('Normal', 6), ('Anomaly', 1), ('Normal', 3), ('Anomaly', 1), ('Normal', 12), ('Anomaly', 1), ('Normal', 2), ('Anomaly', 1), ('Normal', 3), ('Anomaly', 1), ('Normal', 10), ('Anomaly', 1), ('Normal', 9), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 1 ...
# >
# Remove rows:  [0, 1]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [5, 6]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [8, 8]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [21, 21]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [26, 26]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [32, 32]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [36, 36]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42, 42]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [44, 44]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [48, 48]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [51, 51]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [58, 59]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [64, 65]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [75, 75]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [78, 78]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [97, 97]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [102, 102]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [108, 108]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [110, 110]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [112, 112]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [115, 116]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [118, 118]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [131, 131]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [151, 151]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [156, 156]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [162, 162]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [171, 171]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [174, 174]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [176, 177]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [182, 183]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [185, 185]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [187, 187]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [196, 197]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [200, 200]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [202, 202]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [207, 207]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [225, 226]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [228, 228]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [233, 233]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [238, 238]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [247, 247]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [253, 253]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [257, 257]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [264, 264]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [268, 268]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [277, 277]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [279, 279]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [283, 283]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [287, 288]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [293, 293]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [296, 296]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [299, 299]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [301, 301]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [313, 313]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [320, 320]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [330, 330]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [333, 333]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [336, 336]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [348, 348]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [350, 350]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [354, 354]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [357, 357]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [359, 359]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [364, 364]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [366, 366]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [370, 370]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [372, 372]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [394, 396]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [401, 401]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [410, 410]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [422, 422]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [427, 427]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [430, 430]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [435, 436]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [438, 438]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [443, 443]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [446, 446]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [449, 449]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [464, 465]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [467, 467]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [478, 479]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [482, 482]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [484, 484]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [502, 503]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [506, 507]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [510, 511]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [513, 513]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [531, 531]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [535, 537]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [542, 542]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [547, 547]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [558, 558]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [567, 567]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [578, 578]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [591, 591]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [595, 595]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [612, 612]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [617, 617]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [619, 619]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [634, 634]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [636, 636]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [646, 646]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [661, 661]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [666, 666]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [669, 669]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [680, 680]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [692, 692]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [697, 697]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [703, 703]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [705, 705]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [707, 707]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [721, 722]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [735, 735]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [739, 739]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [751, 752]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [758, 762]
# Removing 5 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [766, 766]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [770, 770]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [776, 777]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [791, 791]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [798, 798]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [802, 802]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [815, 815]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [818, 818]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [822, 822]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [833, 833]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [843, 843]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [845, 845]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [847, 848]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [853, 853]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [856, 856]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [875, 875]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [888, 888]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [891, 892]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [908, 909]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [916, 916]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [918, 918]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [921, 921]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [926, 926]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [932, 932]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [940, 941]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [943, 943]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [948, 948]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [954, 954]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [956, 956]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [958, 958]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [963, 963]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [967, 969]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [981, 981]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [985, 985]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [990, 990]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [994, 994]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [997, 997]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1007, 1007]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1011, 1011]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1015, 1015]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1017, 1017]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1020, 1020]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1032, 1032]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1036, 1038]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1044, 1044]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1047, 1047]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1052, 1052]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1057, 1058]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1061, 1062]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1065, 1065]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1069, 1069]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1099, 1100]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1105, 1105]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1108, 1108]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1112, 1112]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1122, 1122]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1125, 1126]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1131, 1132]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1139, 1139]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1152, 1152]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1155, 1155]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1158, 1162]
# Removing 5 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1165, 1168]
# Removing 4 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1175, 1175]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1178, 1178]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1182, 1182]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1186, 1186]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1188, 1188]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1192, 1192]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1195, 1195]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1197, 1197]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1199, 1199]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1202, 1202]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1206, 1206]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1209, 1209]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1236, 1237]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1241, 1241]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1243, 1243]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1248, 1249]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1257, 1257]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1263, 1263]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1268, 1269]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1274, 1274]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1290, 1291]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1293, 1293]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1297, 1297]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1306, 1307]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1310, 1311]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1314, 1314]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1317, 1317]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1321, 1321]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1325, 1325]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1328, 1328]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1330, 1330]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1335, 1335]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1337, 1337]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1349, 1349]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1364, 1364]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1369, 1371]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1384, 1384]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1389, 1390]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1396, 1396]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1398, 1398]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1411, 1411]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1420, 1420]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1433, 1433]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1441, 1441]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1453, 1453]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1460, 1460]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1462, 1462]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1467, 1467]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1473, 1475]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1478, 1479]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1484, 1484]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1490, 1491]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1493, 1493]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1512, 1513]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1519, 1519]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1522, 1524]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1529, 1529]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1532, 1532]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1550, 1551]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1553, 1553]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1585, 1585]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1588, 1588]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1594, 1594]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1596, 1597]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1600, 1600]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1602, 1603]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1606, 1606]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1610, 1610]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1612, 1612]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1614, 1614]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1622, 1622]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1631, 1632]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1634, 1635]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1648, 1648]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1650, 1650]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1653, 1653]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1656, 1656]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1665, 1666]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1674, 1676]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1687, 1687]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1689, 1689]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1693, 1694]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1702, 1702]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1704, 1705]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1708, 1709]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1712, 1712]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1718, 1718]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1720, 1720]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1726, 1726]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1728, 1728]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1736, 1737]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1740, 1740]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1745, 1745]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1747, 1747]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1751, 1752]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1754, 1754]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1759, 1759]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1761, 1761]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1763, 1763]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1771, 1771]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1775, 1775]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1778, 1778]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1785, 1785]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1787, 1787]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1792, 1792]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1799, 1802]
# Removing 4 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1812, 1812]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1815, 1816]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1820, 1820]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1822, 1822]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1838, 1840]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1842, 1842]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1845, 1845]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1852, 1852]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1855, 1855]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1863, 1863]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1868, 1869]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1873, 1873]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1876, 1876]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1879, 1880]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1886, 1886]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1891, 1891]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1900, 1900]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1904, 1904]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1909, 1909]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1915, 1915]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1925, 1925]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1927, 1927]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1940, 1940]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1942, 1942]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1944, 1944]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1946, 1946]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1949, 1949]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1954, 1954]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1958, 1958]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1960, 1960]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1964, 1964]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1966, 1966]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1975, 1976]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2000, 2000]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2006, 2007]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2010, 2010]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2013, 2013]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2016, 2016]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2020, 2021]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2025, 2025]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2028, 2028]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2031, 2031]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2034, 2034]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2047, 2047]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2057, 2057]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2068, 2068]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2074, 2075]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2085, 2087]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2090, 2090]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2096, 2096]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2099, 2099]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2106, 2107]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2110, 2111]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2113, 2113]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2116, 2116]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2118, 2118]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2125, 2125]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2128, 2129]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2131, 2131]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2134, 2134]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2144, 2144]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2149, 2149]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2156, 2156]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2159, 2159]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2161, 2161]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2164, 2164]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2166, 2166]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2176, 2176]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2190, 2190]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2192, 2192]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2200, 2200]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2212, 2212]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2217, 2217]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2219, 2219]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2224, 2224]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2226, 2226]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2229, 2229]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2234, 2234]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2237, 2237]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2242, 2242]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2246, 2246]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2255, 2256]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2259, 2259]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2264, 2264]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2268, 2268]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2273, 2273]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2281, 2281]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2283, 2283]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2293, 2293]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2296, 2297]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2301, 2301]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2308, 2308]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2310, 2310]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2312, 2312]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2317, 2317]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2320, 2321]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2328, 2328]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2335, 2335]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2345, 2345]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2347, 2347]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2353, 2354]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2357, 2358]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2365, 2366]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2375, 2375]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2377, 2377]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2384, 2386]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2390, 2390]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2392, 2392]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2394, 2395]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2399, 2400]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2403, 2403]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2410, 2410]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2414, 2414]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2421, 2422]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2425, 2425]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2429, 2429]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2432, 2432]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2438, 2438]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2442, 2442]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2445, 2445]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2451, 2451]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2456, 2457]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2459, 2459]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2464, 2464]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2471, 2471]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2475, 2475]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2485, 2485]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2491, 2491]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2494, 2494]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2496, 2496]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2499, 2499]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2505, 2505]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2511, 2511]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2514, 2514]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2524, 2525]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2531, 2531]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2538, 2538]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2540, 2540]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2546, 2546]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2549, 2549]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2551, 2551]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2554, 2554]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2556, 2556]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2562, 2562]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2569, 2569]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2572, 2573]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2578, 2578]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2583, 2588]
# Removing 6 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2591, 2591]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2593, 2594]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2600, 2600]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2602, 2602]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2610, 2611]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2625, 2626]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2647, 2648]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2655, 2655]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2658, 2659]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2661, 2662]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2665, 2665]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2667, 2667]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2672, 2674]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2679, 2679]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2681, 2681]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2689, 2689]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2705, 2705]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2709, 2710]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2712, 2712]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2720, 2720]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2744, 2744]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2749, 2749]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2754, 2754]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2771, 2771]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2773, 2773]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2783, 2784]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2789, 2789]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2793, 2793]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2795, 2795]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2808, 2808]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2812, 2812]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2824, 2824]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2834, 2834]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2837, 2837]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2841, 2841]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2846, 2846]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2848, 2848]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2850, 2850]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2852, 2852]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2855, 2855]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2857, 2857]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2865, 2865]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2869, 2869]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2872, 2872]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2876, 2876]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2878, 2878]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2885, 2885]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2889, 2889]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2891, 2891]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2894, 2894]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2897, 2897]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2899, 2900]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2902, 2903]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2906, 2906]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2922, 2922]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2925, 2925]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2927, 2927]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2929, 2929]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2932, 2932]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2934, 2936]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2941, 2941]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2945, 2945]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2947, 2947]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2951, 2951]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2963, 2964]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2969, 2969]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2975, 2975]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2986, 2986]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2988, 2988]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2991, 2991]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2999, 2999]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3020, 3020]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3023, 3023]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3026, 3026]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3030, 3030]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3032, 3034]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3039, 3039]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3046, 3046]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3063, 3063]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3065, 3066]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3073, 3073]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3075, 3075]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3080, 3080]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3082, 3082]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3088, 3088]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3090, 3090]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3093, 3093]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3109, 3109]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3111, 3111]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3114, 3114]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3117, 3117]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3121, 3121]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3124, 3124]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3133, 3133]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3136, 3136]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3149, 3149]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3151, 3151]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3158, 3158]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3166, 3166]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3168, 3168]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3176, 3177]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3184, 3185]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3192, 3194]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3201, 3201]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3204, 3205]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3212, 3212]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3215, 3215]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3219, 3219]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3222, 3222]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3233, 3233]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3236, 3236]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3245, 3245]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3247, 3247]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3251, 3251]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3253, 3253]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3255, 3255]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3257, 3257]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3276, 3276]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3278, 3279]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3301, 3301]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# ...
# >
# Remove rows:  [42313, 42314]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42318, 42318]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42322, 42322]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42324, 42324]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42331, 42331]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42338, 42338]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42350, 42350]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42355, 42355]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42359, 42359]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42361, 42361]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42365, 42366]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42369, 42369]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42372, 42372]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42380, 42380]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42389, 42389]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42392, 42392]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42397, 42397]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42407, 42407]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42410, 42411]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42413, 42413]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42423, 42423]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42428, 42428]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42431, 42431]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42440, 42440]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42442, 42442]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42448, 42448]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42452, 42452]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42456, 42456]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42462, 42463]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42467, 42467]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42475, 42475]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42478, 42479]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42499, 42500]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42503, 42504]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42511, 42511]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42521, 42521]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42523, 42523]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42526, 42526]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42531, 42531]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42535, 42537]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42539, 42539]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42549, 42549]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42551, 42551]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42561, 42564]
# Removing 4 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42570, 42570]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42577, 42577]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42587, 42588]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42590, 42590]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42593, 42593]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42601, 42602]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42614, 42614]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42617, 42618]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42621, 42621]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42635, 42635]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42637, 42637]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42642, 42642]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42650, 42650]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42657, 42657]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42659, 42659]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42661, 42661]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42666, 42666]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42677, 42678]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42681, 42681]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42686, 42687]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42691, 42691]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42693, 42693]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42723, 42723]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42727, 42727]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42730, 42730]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42732, 42732]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42735, 42735]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42750, 42750]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42754, 42754]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42758, 42758]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42763, 42763]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42765, 42765]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42781, 42781]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42783, 42783]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42795, 42795]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42800, 42800]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42803, 42803]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42812, 42812]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42815, 42817]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42821, 42821]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42828, 42828]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42830, 42830]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42834, 42834]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42844, 42844]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42846, 42846]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42848, 42848]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42857, 42857]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42859, 42859]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42861, 42861]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42868, 42870]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42872, 42872]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42886, 42887]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42890, 42890]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42897, 42897]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42900, 42900]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42905, 42905]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42916, 42916]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42920, 42920]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42923, 42924]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42931, 42932]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42935, 42936]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42938, 42938]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42942, 42942]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42946, 42946]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42948, 42948]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42951, 42951]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42953, 42953]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42957, 42957]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42963, 42963]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42966, 42966]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42969, 42969]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42978, 42978]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42982, 42982]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42986, 42986]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42988, 42988]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [42993, 42993]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43000, 43000]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43011, 43012]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43026, 43026]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43030, 43030]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43033, 43035]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43046, 43046]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43054, 43055]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43060, 43060]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43062, 43062]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43067, 43067]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43071, 43071]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43080, 43080]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43088, 43088]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43109, 43109]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43112, 43112]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43115, 43115]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43117, 43117]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43128, 43131]
# Removing 4 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43147, 43147]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43162, 43162]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43165, 43165]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43168, 43168]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43179, 43179]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43183, 43184]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43189, 43189]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43192, 43194]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43210, 43210]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43212, 43213]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43215, 43215]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43217, 43217]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43221, 43221]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43223, 43223]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43225, 43225]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43230, 43230]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43239, 43240]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43242, 43242]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43251, 43251]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43257, 43257]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43266, 43266]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43271, 43271]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43273, 43273]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43281, 43282]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43286, 43286]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43290, 43290]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43304, 43304]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43323, 43324]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43342, 43342]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43348, 43348]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43358, 43358]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43363, 43364]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43375, 43375]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43377, 43377]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43381, 43381]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43384, 43384]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43387, 43387]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43397, 43397]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43402, 43402]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43404, 43404]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43406, 43406]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43411, 43413]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43415, 43415]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43417, 43418]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43426, 43430]
# Removing 5 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43433, 43433]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43439, 43439]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43447, 43448]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43451, 43453]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43456, 43456]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43466, 43466]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43469, 43469]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43476, 43476]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43481, 43481]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43484, 43485]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43487, 43487]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43492, 43492]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...

# %%
# Check row counts
tot_rows = len(df_norm_train) + len(df_abnorm_train)
print('Nrows normal: ' + str(len(df_norm_train)) + ' (' + str(round(100*len(df_norm_train)/tot_rows)) + '%)')
print('Nrows abnorm: ' + str(len(df_abnorm_train)) + ' (' + str(round(100*len(df_abnorm_train)/tot_rows)) + '%)')
# Out:
# Nrows normal: 34108 (78%)
# Nrows abnorm: 9392 (22%)

# %% [raw]
# # Check the results of row removal
# include_cols = ['volt', 'rotate', 'pressure', 'vibration']
# df_plot = df_norm.loc[:,include_cols]
# for sen in df_plot.columns:
#     df_plot[[sen]].plot(figsize = (18, 4), color = 'black', marker = 'o')

# %%
df_norm_train
# Out:
#               rad01     rad02     rad03     rad04     rad05     rad06  \
# timestamp
# 3          0.487167  0.476562  0.507015  0.384615  0.512617  0.503268
# 4          0.487167  0.429688  0.507015  0.346154  0.513469  0.575163
# 5          0.487167  0.453125  0.507015  0.355769  0.511839  0.594771
# 8          0.487065  0.578125  0.506629  0.387821  0.512654  0.575163
# 10         0.487167  0.625000  0.506114  0.346154  0.512802  0.732026
# ...             ...       ...       ...       ...       ...       ...
# 43496      0.487672  0.445312  0.507015  0.375000  0.512988  0.522876
# 43497      0.487167  0.453125  0.506886  0.317308  0.512914  0.594771
# 43498      0.487167  0.445312  0.507401  0.375000  0.512802  0.509804
# 43499      0.487167  0.453125  0.507015  0.362179  0.511876  0.562092
# 43500      0.486863  0.617188  0.507015  0.362179  0.512802  0.712418
#
#               rad07     rad08  timestamp   state
# timestamp
# 3          0.614767  0.575563          3  Normal
# 4          0.643660  0.585209          4  Normal
# 5          0.640449  0.575563          5  Normal
# 8          0.632424  0.575563          8  Normal
# 10         0.683788  0.585209         10  Normal
# ...             ...       ...        ...     ...
# 43496      0.617978  0.572347      43496  Normal
# 43497      0.677368  0.614148      43497  Normal
# 43498      0.617978  0.575563      43498  Normal
# 43499      0.630819  0.575563      43499  Normal
# 43500      0.666132  0.575563      43500  Normal
#
# [34108 rows x 10 columns]

# %%
# Use besploke function from pdm_functions
df_norm_test, df_abnorm_test = pdm.remove_segements(
    segment_vec = df_test_scaled['state'],
    mapping = condition_map,
    dat = df_test_scaled,
    trans_window = 0,
    keep = 'Normal'
)
# Out:
# Input segement categories:  ['Anomaly' 'Normal']
# Categories after mapping:  ['Anomaly' 'Normal']
# Run length encoding:  [('Anomaly', 2), ('Normal', 1), ('Anomaly', 1), ('Normal', 7), ('Anomaly', 1), ('Normal', 5), ('Anomaly', 2), ('Normal', 7), ('Anomaly', 1), ('Normal', 8), ('Anomaly', 1), ('Normal', 7), ('Anomaly', 2), ('Normal', 3), ('Anomaly', 1), ('Normal', 3), ('Anomaly', 1), ('Normal', 3), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 3), ('Normal', 1), ('Anomaly', 1), ('Normal', 5), ('Anomaly', 2), ('Normal', 4), ('Anomaly', 1), ('Normal', 17), ('Anomaly', 1), ('Normal', 2), ('Anomaly', 1), ('Normal', 9), ('Anomaly', 1), ('Normal', 3), ('Anomaly', 1), ('Normal', 2), ('Anomaly', 1), ('Normal', 24), ('Anomaly', 2), ('Normal', 1), ('Anomaly', 1), ('Normal', 2), ('Anomaly', 1), ('Normal', 5), ('Anomaly', 1), ('Normal', 3), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 1), ('Normal', 4), ('Anomaly', 1), ('Normal', 12), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 1), ('Normal', 2), ('Anomaly', 1), ('Normal', 7), ('Anomaly', 1), ('Normal', 6), ('Anomaly', 1), ('Normal', 7), ('Anomaly', 1), ('Normal', 3), ('Anomaly', 1), ('Normal', 7), ('Anomaly', 2), ('Normal', 5), ('Anomaly', 2), ('Normal', 3), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 1), ('Normal', 2), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 1), ('Normal', 7), ('Anomaly', 1), ('Normal', 14), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 2), ('Normal', 3), ('Anomaly', 1), ('Normal', 3), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 1), ('Normal', 3), ('Anomaly', 1), ('Normal', 4), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 1), ('Normal', 8), ('Anomaly', 1), ('Normal', 7), ('Anomaly', 2), ('Normal', 10), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 1), ('Normal', 2), ('Anomaly', 1), ('Normal', 6), ('Anomaly', 1), ('Normal', 3), ('Anomaly', 1), ('Normal', 17), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 4), ('Normal', 1), ('Anomaly', 1), ('Normal', 2), ('Anomaly', 2), ('Normal', 10), ('Anomaly', 1), ('Normal', 4), ('Anomaly', 1), ('Normal', 3), ('Anomaly', 1), ('Normal', 3), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 1), ('Normal', 3), ('Anomaly', 1), ('Normal', 7), ('Anomaly', 1), ('Normal', 2), ('Anomaly', 2), ('Normal', 3), ('Anomaly', 1), ('Normal', 2), ('Anomaly', 1), ('Normal', 8), ('Anomaly', 1), ('Normal', 22), ('Anomaly', 1), ('Normal', 22), ('Anomaly', 1), ('Normal', 8), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 1), ('Normal', 5), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 1), ('Normal', 12), ('Anomaly', 1), ('Normal', 4), ('Anomaly', 2), ('Normal', 2), ('Anomaly', 1), ('Normal', 2), ('Anomaly', 2), ('Normal', 2), ('Anomaly', 1), ('Normal', 2), ('Anomaly', 1), ('Normal', 15), ('Anomaly', 1), ('Normal', 24), ('Anomaly', 1), ('Normal', 4), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 1), ('Normal', 7), ('Anomaly', 1), ('Normal', 6), ('Anomaly', 2), ('Normal', 3), ('Anomaly', 2), ('Normal', 2), ('Anomaly', 1), ('Normal', 2), ('Anomaly', 1), ('Normal', 3), ('Anomaly', 2), ('Normal', 11), ('Anomaly', 1), ('Normal', 3), ('Anomaly', 1), ('Normal', 3), ('Anomaly', 1), ('Normal', 8), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 1), ('Normal', 9), ('Anomaly', 1), ('Normal', 2), ('Anomaly', 1), ('Normal', 5), ('Anomaly', 2), ('Normal', 5), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 2), ('Normal', 8), ('Anomaly', 2), ('Normal', 9), ('Anomaly', 1), ('Normal', 2), ('Anomaly', 4), ('Normal', 5), ('Anomaly', 1), ('Normal', 4), ('Anomaly', 2), ('Normal', 4), ('Anomaly', 2), ('Normal', 14), ('Anomaly', 1), ('Normal', 5), ('Anomaly', 1), ('Normal', 5), ('Anomaly', 2), ('Normal', 7), ('Anomaly', 1), ('Normal', 6), ('Anomaly', 1), ('Normal', 11), ('Anomaly', 1), ('Normal', 2), ('Anomaly', 1), ('Normal', 1), ('Anomaly', 1), ('Normal', 4), ('Anomaly', 1), ('Normal', 3), ('Anomaly', 1), ('Normal', 3), ('Anomaly', 1), ('Normal', 4), ('Anomaly', 1), ('Normal', 4), ('Anomaly', 1), ('Normal', 11), ('Anomaly', 1), ('Normal', 6), ('Anomaly', 1), ('Normal ...
# >
# Remove rows:  [0, 1]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3, 3]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [11, 11]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [17, 18]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [26, 26]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [35, 35]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [43, 44]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [48, 48]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [52, 52]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [56, 56]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [58, 60]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [62, 62]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [68, 69]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [74, 74]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [92, 92]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [95, 95]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [105, 105]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [109, 109]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [112, 112]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [137, 138]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [140, 140]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [143, 143]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [149, 149]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [153, 153]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [155, 155]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [157, 157]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [159, 159]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [164, 164]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [177, 177]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [179, 179]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [181, 181]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [184, 184]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [192, 192]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [199, 199]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [207, 207]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [211, 211]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [219, 220]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [226, 227]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [231, 231]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [233, 233]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [236, 236]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [238, 238]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [240, 240]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [248, 248]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [263, 263]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [265, 265]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [267, 268]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [272, 272]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [276, 276]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [278, 278]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [282, 282]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [287, 287]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [289, 289]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [298, 298]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [306, 307]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [318, 318]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [320, 320]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [323, 323]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [330, 330]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [334, 334]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [352, 352]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [354, 357]
# Removing 4 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [359, 359]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [362, 363]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [374, 374]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [379, 379]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [383, 383]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [387, 387]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [389, 389]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [393, 393]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [401, 401]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [404, 405]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [409, 409]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [412, 412]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [421, 421]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [444, 444]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [467, 467]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [476, 476]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [478, 478]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [484, 484]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [486, 486]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [499, 499]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [504, 505]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [508, 508]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [511, 512]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [515, 515]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [518, 518]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [534, 534]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [559, 559]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [564, 564]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [566, 566]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [574, 574]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [581, 582]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [586, 587]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [590, 590]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [593, 593]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [597, 598]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [610, 610]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [614, 614]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [618, 618]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [627, 627]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [629, 629]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [639, 639]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [642, 642]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [648, 649]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [655, 655]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [657, 658]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [667, 668]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [678, 678]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [681, 684]
# Removing 4 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [690, 690]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [695, 696]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [701, 702]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [717, 717]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [723, 723]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [729, 730]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [738, 738]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [745, 745]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [757, 757]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [760, 760]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [762, 762]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [767, 767]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [771, 771]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [775, 775]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [780, 780]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [785, 785]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [797, 797]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [804, 804]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [808, 808]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [810, 811]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [819, 819]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [825, 825]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [844, 844]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [846, 847]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [849, 849]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [852, 852]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [865, 865]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [867, 867]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [873, 873]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [876, 876]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [880, 881]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [905, 905]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [907, 907]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [911, 912]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [916, 916]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [919, 919]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [924, 924]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [931, 932]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [935, 935]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [938, 938]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [953, 953]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [959, 960]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [962, 965]
# Removing 4 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [967, 967]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [971, 971]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [974, 974]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [996, 996]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [999, 999]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1011, 1011]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1014, 1014]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1025, 1025]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1034, 1034]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1036, 1036]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1046, 1046]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1050, 1050]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1055, 1056]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1062, 1062]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1067, 1067]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1072, 1072]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1075, 1075]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1078, 1078]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1087, 1087]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1104, 1105]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1107, 1108]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1116, 1119]
# Removing 4 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1126, 1126]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1135, 1136]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1143, 1143]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1146, 1146]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1150, 1150]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1153, 1153]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1161, 1161]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1172, 1172]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1179, 1179]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1183, 1183]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1185, 1185]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1187, 1187]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1189, 1189]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1204, 1204]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1207, 1207]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1214, 1214]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1229, 1229]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1232, 1232]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1234, 1234]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1236, 1236]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1240, 1240]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1243, 1243]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1247, 1247]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1249, 1249]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1254, 1254]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1258, 1258]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1266, 1267]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1271, 1271]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1274, 1274]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1286, 1286]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1290, 1291]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1299, 1299]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1306, 1306]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1312, 1313]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1323, 1323]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1326, 1326]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1328, 1329]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1334, 1334]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1339, 1339]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1341, 1341]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1348, 1348]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1350, 1350]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1354, 1354]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1360, 1361]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1365, 1365]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1372, 1372]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1377, 1377]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1383, 1383]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1386, 1386]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1388, 1388]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1394, 1394]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1403, 1403]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1405, 1406]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1411, 1411]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1413, 1413]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1419, 1419]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1421, 1421]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1429, 1429]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1440, 1443]
# Removing 4 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1445, 1445]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1460, 1461]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1463, 1464]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1473, 1474]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1492, 1492]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1494, 1494]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1498, 1498]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1504, 1504]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1506, 1506]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1511, 1512]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1514, 1514]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1523, 1525]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1528, 1528]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1530, 1530]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1534, 1534]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1537, 1537]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1544, 1546]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1549, 1549]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1554, 1555]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1560, 1560]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1564, 1565]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1568, 1568]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1570, 1571]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1578, 1578]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1584, 1584]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1588, 1588]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1595, 1595]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1602, 1602]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1607, 1607]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1610, 1610]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1614, 1615]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1618, 1618]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1620, 1620]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1626, 1627]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1645, 1645]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1647, 1647]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1661, 1663]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1671, 1671]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1677, 1677]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1681, 1681]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1690, 1690]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1692, 1692]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1697, 1697]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1699, 1701]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1703, 1703]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1711, 1711]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1715, 1715]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1718, 1718]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1722, 1722]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1725, 1725]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1736, 1736]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1742, 1742]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1744, 1744]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1748, 1748]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1751, 1751]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1758, 1758]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1768, 1769]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1776, 1776]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1783, 1783]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1785, 1785]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1787, 1787]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1790, 1790]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1797, 1797]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1807, 1807]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1819, 1819]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1830, 1830]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1835, 1836]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1864, 1864]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1880, 1881]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1886, 1886]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1893, 1894]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1896, 1896]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1905, 1905]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1907, 1907]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1914, 1914]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1916, 1916]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1919, 1920]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1925, 1925]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1930, 1930]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1932, 1932]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1934, 1936]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1942, 1942]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1945, 1945]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1956, 1956]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1965, 1966]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1969, 1969]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1977, 1977]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1989, 1989]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1997, 1997]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [1999, 1999]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2004, 2005]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2007, 2007]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2012, 2013]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2018, 2018]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2034, 2034]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2039, 2039]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2053, 2054]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2062, 2062]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2066, 2066]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2070, 2070]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2072, 2072]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2074, 2074]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2079, 2079]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2082, 2083]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2088, 2088]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2093, 2093]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2095, 2095]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2097, 2097]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2101, 2101]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2103, 2103]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2105, 2105]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2107, 2108]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2111, 2111]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2115, 2115]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2121, 2121]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2125, 2125]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2131, 2131]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2134, 2134]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2144, 2144]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2146, 2146]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2148, 2148]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2151, 2151]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2154, 2154]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2160, 2161]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2163, 2163]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2165, 2166]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2172, 2174]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2178, 2179]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2181, 2181]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2190, 2190]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2197, 2197]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2218, 2218]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2220, 2220]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2235, 2236]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2243, 2243]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2253, 2253]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2255, 2255]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2257, 2257]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2259, 2259]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2264, 2264]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2266, 2266]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2272, 2272]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2289, 2289]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2291, 2291]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2294, 2294]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2303, 2304]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2309, 2309]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2313, 2313]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2321, 2322]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2325, 2325]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2328, 2329]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2341, 2341]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2349, 2349]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2354, 2354]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2364, 2364]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2373, 2374]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2378, 2378]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2396, 2396]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2398, 2398]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2401, 2401]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2405, 2405]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2409, 2409]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2418, 2418]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2420, 2420]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2425, 2425]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2429, 2429]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2443, 2443]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2450, 2451]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2453, 2454]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2461, 2462]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2464, 2465]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2470, 2470]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2476, 2476]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2480, 2480]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2489, 2491]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2495, 2495]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2498, 2499]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2502, 2502]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2506, 2506]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2516, 2516]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2518, 2518]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2524, 2524]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2528, 2528]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2540, 2541]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2544, 2544]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2548, 2548]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2556, 2556]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2559, 2560]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2566, 2567]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2573, 2573]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2591, 2591]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2595, 2595]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2598, 2598]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2600, 2601]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2604, 2604]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2614, 2614]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2619, 2619]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2636, 2636]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2642, 2642]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2649, 2649]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2651, 2652]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2657, 2659]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2667, 2669]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2671, 2671]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2679, 2679]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2681, 2681]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2689, 2691]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2693, 2693]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2697, 2697]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2701, 2702]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2704, 2704]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2707, 2708]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2710, 2710]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2724, 2725]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2727, 2729]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2733, 2733]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2743, 2744]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2746, 2746]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2750, 2750]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2752, 2752]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2754, 2754]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2757, 2757]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2760, 2760]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2763, 2764]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2774, 2774]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2781, 2781]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2783, 2783]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2786, 2788]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2794, 2794]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2797, 2797]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2804, 2804]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2810, 2810]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2822, 2822]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2828, 2828]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2830, 2830]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2842, 2842]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2844, 2844]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2849, 2849]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2853, 2853]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2863, 2864]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2868, 2868]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2875, 2875]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2877, 2877]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2881, 2882]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2890, 2890]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2904, 2904]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2910, 2910]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2919, 2920]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2924, 2924]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2927, 2927]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2931, 2931]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2943, 2944]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2947, 2948]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2950, 2950]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2954, 2955]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2957, 2957]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2964, 2964]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2970, 2970]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2972, 2972]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2975, 2975]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2981, 2981]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2984, 2984]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [2999, 3000]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3004, 3004]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3007, 3007]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3011, 3011]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3014, 3014]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3020, 3020]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3042, 3042]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3050, 3050]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3057, 3057]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3062, 3062]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3064, 3064]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3067, 3069]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3078, 3078]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3085, 3085]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3092, 3092]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3096, 3096]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3103, 3103]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3105, 3105]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3109, 3109]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3117, 3117]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3120, 3120]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3123, 3123]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3125, 3125]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3130, 3131]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3134, 3134]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3138, 3138]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3142, 3143]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3161, 3162]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3165, 3165]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3173, 3173]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3176, 3176]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3182, 3182]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3184, 3184]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3186, 3186]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3190, 3190]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3194, 3194]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3196, 3196]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3198, 3199]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3206, 3206]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3212, 3212]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3214, 3214]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3221, 3221]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3224, 3224]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3228, 3228]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3234, 3234]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3237, 3237]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3241, 3241]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3246, 3247]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3270, 3270]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3272, 3273]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3279, 3279]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3287, 3287]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3292, 3292]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3301, 3301]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3305, 3305]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3307, 3307]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [3310, 3311]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# ...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13397, 13398]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13401, 13401]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13409, 13409]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13411, 13411]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13423, 13423]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13425, 13425]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13434, 13435]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13449, 13449]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13455, 13456]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13458, 13458]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13460, 13460]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13470, 13470]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13474, 13475]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13484, 13484]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13492, 13492]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13494, 13494]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13504, 13504]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13507, 13508]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13514, 13514]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13519, 13519]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13521, 13521]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13528, 13528]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13530, 13530]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13541, 13541]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13545, 13546]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13548, 13548]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13550, 13550]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13554, 13554]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13557, 13557]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13562, 13564]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13569, 13570]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13574, 13574]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13582, 13586]
# Removing 5 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13607, 13609]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13616, 13620]
# Removing 5 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13625, 13625]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13627, 13627]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13639, 13639]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13643, 13643]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13645, 13646]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13650, 13650]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13665, 13666]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13676, 13676]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13678, 13678]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13680, 13680]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13685, 13686]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13690, 13690]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13692, 13693]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13695, 13695]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13701, 13701]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13707, 13707]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13709, 13709]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13713, 13713]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13715, 13715]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13717, 13717]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13720, 13720]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13738, 13738]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13743, 13743]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13746, 13747]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13752, 13753]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13763, 13763]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13766, 13766]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13776, 13776]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13779, 13779]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13783, 13783]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13805, 13805]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13807, 13807]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13812, 13812]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13818, 13819]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13825, 13825]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13837, 13840]
# Removing 4 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13845, 13845]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13847, 13848]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13850, 13851]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13863, 13863]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13870, 13870]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13872, 13872]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13874, 13874]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13877, 13877]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13880, 13880]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13882, 13882]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13885, 13885]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13893, 13893]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13895, 13895]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13898, 13899]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13903, 13903]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13907, 13908]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13918, 13918]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13920, 13920]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13925, 13926]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13928, 13928]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13932, 13932]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13947, 13947]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13949, 13949]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13951, 13951]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13964, 13964]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13966, 13966]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13970, 13970]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13980, 13982]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13991, 13991]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [13996, 13998]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14000, 14000]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14009, 14009]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14011, 14011]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14017, 14017]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14021, 14021]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14024, 14025]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14031, 14033]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14035, 14036]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14040, 14041]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14048, 14048]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14060, 14060]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14063, 14063]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14067, 14068]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14077, 14077]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14079, 14079]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14086, 14086]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14091, 14091]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14101, 14101]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14108, 14108]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14112, 14113]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14118, 14118]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14120, 14121]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14123, 14123]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14128, 14129]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14131, 14131]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14138, 14139]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14141, 14142]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14145, 14145]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14147, 14147]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14149, 14149]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14152, 14152]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14154, 14156]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14172, 14172]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14174, 14174]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14177, 14178]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14183, 14183]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14189, 14189]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14194, 14194]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14196, 14196]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14198, 14198]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14202, 14202]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14204, 14204]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14206, 14206]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14220, 14220]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14227, 14227]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14232, 14232]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14236, 14236]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14241, 14241]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14243, 14243]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14250, 14250]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14252, 14252]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14257, 14257]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14260, 14262]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14267, 14267]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14278, 14278]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14284, 14284]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14291, 14291]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14314, 14315]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14318, 14318]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14324, 14325]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14328, 14328]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14331, 14331]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14335, 14335]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14338, 14338]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14341, 14341]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14345, 14345]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14347, 14347]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14352, 14352]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14357, 14357]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14360, 14360]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14376, 14376]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14381, 14383]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14388, 14388]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14395, 14395]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14397, 14397]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14402, 14402]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14416, 14417]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14421, 14421]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14423, 14423]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14429, 14429]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14432, 14432]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14436, 14436]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14438, 14438]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14444, 14444]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14456, 14457]
# Removing 2 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14463, 14463]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14470, 14470]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14474, 14474]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14478, 14478]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14480, 14480]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14482, 14482]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14491, 14491]
# Removing 1 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14495, 14497]
# Removing 3 rows...
# >
# Skipping Normal segment(s)...
# >
# Remove rows:  [14499, 14499]
# Removing 1 rows...

# %%
df_norm_train
# Out:
#               rad01     rad02     rad03     rad04     rad05     rad06  \
# timestamp
# 3          0.487167  0.476562  0.507015  0.384615  0.512617  0.503268
# 4          0.487167  0.429688  0.507015  0.346154  0.513469  0.575163
# 5          0.487167  0.453125  0.507015  0.355769  0.511839  0.594771
# 8          0.487065  0.578125  0.506629  0.387821  0.512654  0.575163
# 10         0.487167  0.625000  0.506114  0.346154  0.512802  0.732026
# ...             ...       ...       ...       ...       ...       ...
# 43496      0.487672  0.445312  0.507015  0.375000  0.512988  0.522876
# 43497      0.487167  0.453125  0.506886  0.317308  0.512914  0.594771
# 43498      0.487167  0.445312  0.507401  0.375000  0.512802  0.509804
# 43499      0.487167  0.453125  0.507015  0.362179  0.511876  0.562092
# 43500      0.486863  0.617188  0.507015  0.362179  0.512802  0.712418
#
#               rad07     rad08  timestamp   state
# timestamp
# 3          0.614767  0.575563          3  Normal
# 4          0.643660  0.585209          4  Normal
# 5          0.640449  0.575563          5  Normal
# 8          0.632424  0.575563          8  Normal
# 10         0.683788  0.585209         10  Normal
# ...             ...       ...        ...     ...
# 43496      0.617978  0.572347      43496  Normal
# 43497      0.677368  0.614148      43497  Normal
# 43498      0.617978  0.575563      43498  Normal
# 43499      0.630819  0.575563      43499  Normal
# 43500      0.666132  0.575563      43500  Normal
#
# [34108 rows x 10 columns]

# %%
# Prepare data for PCA
df_norm_train = df_norm_train.drop(['state', 'timestamp'], axis = 1)                      
df_abnorm_train = df_abnorm_train.drop(['state', 'timestamp'], axis = 1)  

df_norm_test = df_norm_test.drop(['state', 'timestamp'], axis = 1)                      
df_abnorm_test = df_abnorm_test.drop(['state', 'timestamp'], axis = 1)  
df_test = df_test_scaled.drop(['state', 'timestamp'], axis = 1)

# %%
# Define the PCA model (all compoments)
n_comps = 4 # How many dimensions you want to reduce to
pca = PCA(n_components = n_comps, svd_solver = 'full')

# Compute PCA components for the training set
X_train_PCA = pca.fit_transform(df_norm_train)
X_train_PCA = pd.DataFrame(X_train_PCA)
X_train_PCA.index = df_norm_train.index
PCA_count_train_norm = len(X_train_PCA)

# Project the test data onto the PCA space
X_test1_PCA = pca.transform(df_abnorm_train)
X_test1_PCA = pd.DataFrame(X_test1_PCA)
X_test1_PCA.index = df_abnorm_train.index
PCA_count_train_abnorm = len(X_test1_PCA)

# Project the test data onto the PCA space
X_test2_PCA = pca.transform(df_norm_test)
X_test2_PCA = pd.DataFrame(X_test2_PCA)
X_test2_PCA.index = df_norm_test.index
PCA_count_test_norm = len(X_test2_PCA)

# Project the test data onto the PCA space
X_test3_PCA = pca.transform(df_abnorm_test)
X_test3_PCA = pd.DataFrame(X_test3_PCA)
X_test3_PCA.index = df_abnorm_test.index
PCA_count_test_abnorm = len(X_test3_PCA)

# Print the explained variance
# 3 decimal places and don't use scientific notation
np.set_printoptions(precision = 3, suppress=True) 
print('Explained variance:', pca.explained_variance_ratio_)
# Out:
# Explained variance: [0.784 0.174 0.035 0.003]

# %%
# Plot PC1 vs PC2 for training & test sets
fig, axes = plt.subplots(1, 2, figsize = (12, 6))
gs = gridspec.GridSpec(1, 2, width_ratios = [1, 1])

ax0 = plt.subplot(gs[0])
ax0.scatter(X_train_PCA.loc[:, 0], X_train_PCA.loc[:, 1], color = 'green')
ax0.set_xlabel('PC1')
ax0.set_ylabel('PC2')
ax0.set_xlim(-1, 1.5)
ax0.set_ylim(-1, 1)
ax0.set_title('Training Data - Normal')

ax1 = plt.subplot(gs[1])
ax1.scatter(X_test1_PCA.loc[:, 0], X_test1_PCA.loc[:, 1], color = 'grey')
ax1.set_xlabel('PC1')
ax1.set_ylabel('PC2')
ax1.set_xlim(-1, 1.5)
ax1.set_ylim(-1, 1)
ax1.set_title('Validation Data - Abnormal')

plt.show()

# %%
# Plot PC1 vs PC2 for training & test sets
fig, axes = plt.subplots(1, 2, figsize = (12, 6))
gs = gridspec.GridSpec(1, 2, width_ratios = [1, 1])

ax0 = plt.subplot(gs[0])
ax0.scatter(X_test2_PCA.loc[:, 0], X_test2_PCA.loc[:, 1], color = 'green')
ax0.set_xlabel('PC1')
ax0.set_ylabel('PC2')
ax0.set_xlim(-1, 1.5)
ax0.set_ylim(-1, 1)
ax0.set_title('Training Data - Normal')

ax1 = plt.subplot(gs[1])
ax1.scatter(X_test3_PCA.loc[:, 0], X_test3_PCA.loc[:, 1], color = 'grey')
ax1.set_xlabel('PC1')
ax1.set_ylabel('PC2')
ax1.set_xlim(-1, 1.5)
ax1.set_ylim(-1, 1)
ax1.set_title('Validation Data - Abnormal')

plt.show()

# %%
# Move on to calculate Mahalanobis Distance 
# This is a multivatiate distance from centroid calculation that
# can be useful for unsupervised anomaly detection
data_train = np.array(X_train_PCA.values)
data_test1 = np.array(X_test1_PCA.values)
data_test2 = np.array(X_test2_PCA.values)
data_test3 = np.array(X_test3_PCA.values)

cov_matrix = np.cov(data_train, rowvar = False)
inv_cov_matrix = np.linalg.inv(cov_matrix)

# Mean of each column: PC1, PC2 (it should be very close to zero)
mean_distr = data_train.mean(axis = 0) # axis=0 means that average is computed per column
np.set_printoptions(precision = 3, suppress = False)
print('Mean distr', mean_distr)

# Mahalanobis Distance calculation
dist_test1 = pdm.MahalanobisDist(inv_cov_matrix, mean_distr, data_test1, verbose=False)
dist_test2 = pdm.MahalanobisDist(inv_cov_matrix, mean_distr, data_test2, verbose=False)
dist_test3 = pdm.MahalanobisDist(inv_cov_matrix, mean_distr, data_test3, verbose=False)
dist_train = pdm.MahalanobisDist(inv_cov_matrix, mean_distr, data_train, verbose=False)

print("Minimum & maximum MD in training set:", min(dist_train), max(dist_train))
print("Minimum & maximum MD in test set 1  :", min(dist_test1), max(dist_test1))
print("Minimum & maximum MD in test set 2  :", min(dist_test2), max(dist_test2))
print("Minimum & maximum MD in test set 3  :", min(dist_test3), max(dist_test3))

threshold = pdm.MD_threshold(dist_train, extreme = True) # extreme = True; 2x mean of incoming data
print("Threshold value for flagging an anomaly is", "{:.2f}".format(threshold))
# Out:
# Mean distr [ 7.630e-17 -4.469e-17  6.394e-17  3.264e-17]
# Minimum & maximum MD in training set: 0.3052052409514849 83.62179436192514
# Minimum & maximum MD in test set 1  : 0.5807916856548729 88.08226422654771
# Minimum & maximum MD in test set 2  : 0.30922778010863616 109.60645280154392
# Minimum & maximum MD in test set 3  : 0.5807671609020052 168.40924442830928
# Threshold value for flagging an anomaly is 4.55

# %%
import seaborn as sns
plt.figure()
sns.distplot(dist_train,
             bins = 500, 
             kde = True, 
             color = 'green');
plt.xlim([0.0, 8])
plt.xlabel('Mahalanobis dist')
plt.title('Mahalanobis distance distribution for the training data')
plt.show()
# Out:
# /Users/jasonpayne/opt/anaconda3/envs/pdm/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
def prep_mahalonobis_data (dist_dat, thresh, pca_dat):
    # Prepare test data for visualization
    dat = pd.DataFrame()
    dat['Mob dist'] = dist_dat
    dat['Thresh'] = thresh
    dat['Anomaly'] = dat['Mob dist'] > dat['Thresh']
    dat.index = pca_dat.index
    dat['timestamp'] = dat.index

    n_outliers = dat[dat['Anomaly'] == True].shape[0]
    print("There are", n_outliers, "anomalies in the test set out of", dat.shape[0], "points")
    print("Corresponding to " + str(round(100*(n_outliers / dat.shape[0]), 2)) + '%')

    return(dat)

# %%
# Prepare training data for visualization
# If Mahalonobis distance is above threshold: Flag as anomaly
anomaly_train = pdm.prep_mahalonobis_data(dist_train, threshold, X_train_PCA)
anomaly1 = pdm.prep_mahalonobis_data(dist_test1, threshold, X_test1_PCA)
anomaly2 = pdm.prep_mahalonobis_data(dist_test2, threshold, X_test2_PCA)
anomaly3 = pdm.prep_mahalonobis_data(dist_test3, threshold, X_test3_PCA)
# Out:
# There are 228 anomalies in the test set out of 34108 points
# > Corresponding to 0.67%
# There are 5856 anomalies in the test set out of 9392 points
# > Corresponding to 62.35%
# There are 70 anomalies in the test set out of 11478 points
# > Corresponding to 0.61%
# There are 1890 anomalies in the test set out of 3022 points
# > Corresponding to 62.54%

# %%
# Visualize Mahalonobis distance with actual anomalies vs threshold  
fig, ax = plt.subplots(figsize = (18, 4))
ax.scatter(anomaly_train['timestamp'], anomaly_train['Mob dist'], color = 'lightgrey', marker = '.', zorder = 1, label = 'Training Normal')
ax.plot(anomaly_train['timestamp'], anomaly_train['Thresh'], color = 'red', marker = None, linewidth=3, zorder = 2, label = 'MD Threshold')
#ax.scatter(anomaly1['timestamp'], anomaly1['Mob dist'], color = 'orange', marker = '.', zorder = 3, label = 'Boundary Zones')
ax.set_yscale('log')
ax.legend(loc = 'lower right')
plt.show()

# Visualize Mahalonobis distance with actual anomalies vs threshold  
fig, ax = plt.subplots(figsize = (18, 4))
#ax.scatter(anomaly_train['timestamp'], anomaly_train['Mob dist'], color = 'lightgrey', marker = '.', zorder = 1, label = 'Normal')
ax.plot(anomaly1['timestamp'], anomaly1['Thresh'], color = 'red', marker = None, zorder = 2, linewidth=3, label = 'MD Threshold')
ax.scatter(anomaly1['timestamp'], anomaly1['Mob dist'], color = '#CCB7E5', marker = '.', zorder = 1, label = 'Validation Abnormal')
ax.set_yscale('log')
ax.legend(loc = 'lower right')
plt.show()

# %%
# Visualize Mahalonobis distance with actual anomalies vs threshold  
fig, ax = plt.subplots(figsize = (18, 4))
ax.scatter(anomaly2['timestamp'], anomaly2['Mob dist'], color = 'lightgrey', marker = '.', zorder = 1, label = 'Test Normal')
ax.plot(anomaly2['timestamp'], anomaly2['Thresh'], color = 'red', marker = None, linewidth=3, zorder = 2, label = 'MD Threshold')
ax.set_yscale('log')
ax.legend(loc = 'lower right')
plt.show()

# Visualize Mahalonobis distance with actual anomalies vs threshold  
fig, ax = plt.subplots(figsize = (18, 4))
ax.plot(anomaly3['timestamp'], anomaly3['Thresh'], color = 'red', marker = None, zorder = 2, linewidth=3, label = 'MD Threshold')
ax.scatter(anomaly3['timestamp'], anomaly3['Mob dist'], color = '#CCB7E5', marker = '.', zorder = 1, label = 'Test Abnormal')
ax.set_yscale('log')
ax.legend(loc = 'lower right')
plt.show()

# %% [markdown]
# ### Robust Principle Component Analysis (PCA)

# %%
pca_r = PCA(n_components = n_comps, svd_solver = 'full')
df_test.drop('id', axis = 1, inplace = True)
df_test
# Out:
#           rad01     rad02     rad03     rad04     rad05     rad06     rad07  \
# 0      0.487167  0.468750  0.507015  0.291667  0.513210  0.477124  0.707865
# 1      0.487167  0.585938  0.507015  0.384615  0.512654  0.575163  0.637239
# 2      0.487065  0.531250  0.506114  0.381410  0.512802  0.568627  0.630819
# 3      0.488076  0.453125  0.507015  0.368590  0.512728  0.477124  0.626003
# 4      0.487369  0.476562  0.507015  0.387821  0.512580  0.483660  0.611557
# ...         ...       ...       ...       ...       ...       ...       ...
# 14495  0.487167  0.492188  0.507015  0.243590  0.511728  0.339869  0.759230
# 14496  0.487167  0.468750  0.507015  0.269231  0.513729  0.483660  0.730337
# 14497  0.487167  0.437500  0.507015  0.320513  0.511987  0.457516  0.670947
# 14498  0.487167  0.640625  0.507015  0.330128  0.512210  0.745098  0.703050
# 14499  0.487369  0.601562  0.507015  0.384615  0.512840  0.588235  0.640449
#
#           rad08
# 0      0.675241
# 1      0.578778
# 2      0.575563
# 3      0.591640
# 4      0.575563
# ...         ...
# 14495  0.758842
# 14496  0.694534
# 14497  0.639871
# 14498  0.604502
# 14499  0.578778
#
# [14500 rows x 8 columns]

# %%
# Compute all PCA components for the training set
L_train, S_train = pdm.R_pca(df_norm_train).fit()
X_train_PCA = pca_r.fit_transform(L_train)
X_train_PCA = pd.DataFrame(X_train_PCA)
RPCA_count_train_norm = len(X_train_PCA)

# Project the test data onto the PCA space
L_test1, S_test1 = pdm.R_pca(df_abnorm_train).fit()
X_test1_PCA = pca_r.transform(L_test1)
X_test1_PCA = pd.DataFrame(X_test1_PCA)
RPCA_count_train_abnorm = len(X_test1_PCA)

L_test2, S_test2 = pdm.R_pca(df_test).fit()
X_test2_PCA = pca_r.transform(L_test2)
X_test2_PCA = pd.DataFrame(X_test2_PCA)
RPCA_count_test = len(X_test2_PCA)

#L_test3, S_test3 = pdm.R_pca(df_abnorm_test).fit()
#X_test3_PCA = pca.transform(L_test3)
#X_test3_PCA = pd.DataFrame(X_test3_PCA)
#X_test3_PCA.index = df_abnorm_test.index
#RPCA_count_test_abnorm = len(X_test3_PCA)
# Out:
# iteration: 1, error: 0.5208222864723215
# iteration: 100, error: 0.0065156817756406304
# iteration: 200, error: 0.0034210453568610205
# iteration: 300, error: 0.001208961117353208
# iteration: 400, error: 0.00045547733244509226
# iteration: 500, error: 0.00018498470676464273
# iteration: 600, error: 0.0001292696790589403
# iteration: 700, error: 6.939149719751185e-05
# iteration: 800, error: 4.791467937763366e-05
# iteration: 900, error: 3.857141914464569e-05
# iteration: 1000, error: 3.155398194166055e-05
# iteration: 1, error: 0.578320344698833
# iteration: 100, error: 0.002854310684094612
# iteration: 200, error: 0.0017130288492593132
# iteration: 300, error: 0.0009013622633148907
# iteration: 400, error: 0.0006500981402727947
# iteration: 500, error: 0.00045379082318572627
# iteration: 600, error: 0.0004112363680485204
# iteration: 700, error: 0.0002869347601306619
# iteration: 800, error: 0.00019941293937832558
# iteration: 900, error: 0.00015091792482471714
# iteration: 1000, error: 0.0001005731239431944
# iteration: 1, error: 0.5095977016197456
# iteration: 100, error: 0.008578348328141184
# iteration: 200, error: 0.002353000433661322
# iteration: 300, error: 0.00024227217768434193
# iteration: 400, error: 0.0001198641414783303
# iteration: 500, error: 8.701260413137501e-05
# iteration: 600, error: 6.418712354903298e-05
# iteration: 700, error: 5.453410418308153e-05
# iteration: 800, error: 4.983456676175069e-05
# iteration: 900, error: 3.999051016591435e-05
# iteration: 1000, error: 3.1554299294156925e-05

# %%
print(PCA_count_train_norm, RPCA_count_train_norm)
print(PCA_count_train_abnorm, RPCA_count_train_abnorm)
# Out:
# 34108 34108
# 9392 9392

# %%
# Plot PC1 vs PC2 for training & test sets
fig, axes = plt.subplots(1, 2, figsize = (12, 6))
gs = gridspec.GridSpec(1, 2, width_ratios = [1, 1])

ax0 = plt.subplot(gs[0])
ax0.scatter(X_train_PCA.loc[:, 0], X_train_PCA.loc[:, 1], color = 'green')
ax0.set_xlabel('PC1')
ax0.set_ylabel('PC2')
ax0.set_xlim(-0.5, 0.5)
ax0.set_ylim(-0.5, 0.5)
ax0.set_title('Training Data - Normal')

ax1 = plt.subplot(gs[1])
ax1.scatter(X_test1_PCA.loc[:, 0], X_test1_PCA.loc[:, 1], color = 'grey')
ax1.set_xlabel('PC1')
ax1.set_ylabel('PC2')
ax1.set_xlim(-0.5, 0.5)
ax1.set_ylim(-0.5, 0.5)
ax1.set_title('Validation Data - Abnormal')

plt.show()

# %%
X_test2_PCA['state'] = df_test_scaled['state']

# %%
# Plot PC1 vs PC2 for training & test sets
fig, axes = plt.subplots(1, 2, figsize = (12, 6))
gs = gridspec.GridSpec(1, 2, width_ratios = [1, 1])

ax0 = plt.subplot(gs[0])
ax0.scatter(X_test2_PCA.loc[X_test2_PCA['state'] == 'Normal', 0], X_test2_PCA.loc[X_test2_PCA['state'] == 'Normal', 1], color = 'green')
ax0.set_xlabel('PC1')
ax0.set_ylabel('PC2')
ax0.set_xlim(-0.5, 0.5)
ax0.set_ylim(-0.5, 0.5)
ax0.set_title('Test Data - Normal')

ax1 = plt.subplot(gs[1])
ax1.scatter(X_test2_PCA.loc[X_test2_PCA['state'] == 'Anomaly', 0], X_test2_PCA.loc[X_test2_PCA['state'] == 'Anomaly', 1], color = 'grey')
ax1.set_xlabel('PC1')
ax1.set_ylabel('PC2')
ax1.set_xlim(-0.5, 0.5)
ax1.set_ylim(-0.5, 0.5)
ax1.set_title('Test Data - Abnormal')

plt.show()

# %%
# Move on to calculate Mahalanobis Distance 
# This is a multivatiate distance from centroid calculation that
# can be useful for unsupervised anomaly detection
data_train = np.array(X_train_PCA.values)
data_test1 = np.array(X_test1_PCA.values)
data_test2 = np.array(X_test2_PCA.loc[X_test2_PCA['state'] == 'Normal',:].drop('state', axis = 1).values)
data_test3 = np.array(X_test2_PCA.loc[X_test2_PCA['state'] == 'Anomaly',:].drop('state', axis = 1).values)

cov_matrix = np.cov(data_train, rowvar = False)
inv_cov_matrix = np.linalg.inv(cov_matrix)

# Mean of each column: PC1, PC2 (it should be very close to zero)
mean_distr = data_train.mean(axis = 0) # axis=0 means that average is computed per column
np.set_printoptions(precision = 3, suppress = False)
print('Mean distr', mean_distr)

# Mahalanobis Distance calculation
dist_train = pdm.MahalanobisDist(inv_cov_matrix, mean_distr, data_train, verbose=False)
dist_test1 = pdm.MahalanobisDist(inv_cov_matrix, mean_distr, data_test1, verbose=False)
dist_test2 = pdm.MahalanobisDist(inv_cov_matrix, mean_distr, data_test2, verbose=False)
dist_test3 = pdm.MahalanobisDist(inv_cov_matrix, mean_distr, data_test3, verbose=False)

print("Minimum & maximum MD in training set:", min(dist_train), max(dist_train))
print("Minimum & maximum MD in test set 1  :", min(dist_test1), max(dist_test1))
print("Minimum & maximum MD in test set 2  :", min(dist_test2), max(dist_test2))
print("Minimum & maximum MD in test set 3  :", min(dist_test3), max(dist_test3))

threshold = pdm.MD_threshold(dist_train, extreme = True) # extreme = True; 2x mean of incoming data
print("Threshold value for flagging an anomaly is", "{:.2f}".format(threshold))
# Out:
# Mean distr [-1.274e-14 -2.326e-15 -1.757e-14 -1.907e-14]
# Minimum & maximum MD in training set: 0.22690899150140237 156.7495943250656
# Minimum & maximum MD in test set 1  : 50.37445245722612 327.524953795773
# Minimum & maximum MD in test set 2  : 1.0660929206285747 40.69304673248478
# Minimum & maximum MD in test set 3  : 4.8984253628454555 90.79109155501155
# Threshold value for flagging an anomaly is 5.20

# %%
import seaborn as sns
plt.figure()
sns.distplot(dist_train,
             bins = 1000, 
             kde = True, 
             color = 'green');
plt.xlim([0.0, 8])
plt.xlabel('Mahalanobis dist')
plt.title('Mahalanobis distance distribution for the training data')
plt.show()
# Out:
# /Users/jasonpayne/opt/anaconda3/envs/pdm/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Prepare training data for visualization
# If Mahalonobis distance is above threshold: Flag as anomaly
anomaly_train = pdm.prep_mahalonobis_data(dist_train, threshold, X_train_PCA)
anomaly1 = pdm.prep_mahalonobis_data(dist_test1, threshold, X_test1_PCA)
anomaly2 = pdm.prep_mahalonobis_data(dist_test2, threshold, X_test2_PCA.loc[X_test2_PCA['state'] == 'Normal',:])
anomaly3 = pdm.prep_mahalonobis_data(dist_test3, threshold, X_test2_PCA.loc[X_test2_PCA['state'] == 'Anomaly',:])
# Out:
# There are 8 anomalies in the test set out of 34108 points
# > Corresponding to 0.02%
# There are 9392 anomalies in the test set out of 9392 points
# > Corresponding to 100.0%
# There are 8927 anomalies in the test set out of 11478 points
# > Corresponding to 77.77%
# There are 3016 anomalies in the test set out of 3022 points
# > Corresponding to 99.8%

# %%
# Visualize Mahalonobis distance with actual anomalies vs threshold  
fig, ax = plt.subplots(figsize = (18, 4))
ax.scatter(anomaly_train['timestamp'], anomaly_train['Mob dist'], color = 'lightgrey', marker = '.', zorder = 1, label = 'Normal')
ax.plot(anomaly_train['timestamp'], anomaly_train['Thresh'], color = 'red', marker = None, linewidth=3, zorder = 2, label = 'MD Threshold')
#ax.scatter(anomaly1['timestamp'], anomaly1['Mob dist'], color = 'orange', marker = '.', zorder = 3, label = 'Boundary Zones')
ax.set_yscale('log')
ax.legend(loc = 'lower right')
plt.show()

# Visualize Mahalonobis distance with actual anomalies vs threshold  
fig, ax = plt.subplots(figsize = (18, 4))
#ax.scatter(anomaly_train['timestamp'], anomaly_train['Mob dist'], color = 'lightgrey', marker = '.', zorder = 1, label = 'Normal')
ax.plot(anomaly1['timestamp'], anomaly1['Thresh'], color = 'red', marker = None, zorder = 2, linewidth=3, label = 'MD Threshold')
ax.scatter(anomaly1['timestamp'], anomaly1['Mob dist'], color = '#CCB7E5', marker = '.', zorder = 1, label = 'Abnormal')
ax.set_yscale('log')
ax.legend(loc = 'lower right')
plt.show()

# %%
# Visualize Mahalonobis distance with actual anomalies vs threshold  
fig, ax = plt.subplots(figsize = (18, 4))
ax.scatter(anomaly2['timestamp'], anomaly2['Mob dist'], color = 'lightgrey', marker = '.', zorder = 1, label = 'Actual Normal')
ax.plot(anomaly2['timestamp'], anomaly2['Thresh'], color = 'red', marker = None, linewidth=3, zorder = 2, label = 'MD Threshold')
ax.set_yscale('log')
ax.legend(loc = 'lower right')
plt.show()

# Visualize Mahalonobis distance with actual anomalies vs threshold  
fig, ax = plt.subplots(figsize = (18, 4))
ax.plot(anomaly3['timestamp'], anomaly3['Thresh'], color = 'red', marker = None, zorder = 2, linewidth=3, label = 'MD Threshold')
ax.scatter(anomaly3['timestamp'], anomaly3['Mob dist'], color = '#CCB7E5', marker = '.', zorder = 1, label = 'Actual Anomaly')
ax.set_yscale('log')
ax.legend(loc = 'lower right')
plt.show()
